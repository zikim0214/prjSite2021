# %%
import requests
from bs4 import BeautifulSoup
import pymysql
from selenium import webdriver
import time

# %%
def keyword_search(arr):
    a = arr.split()
    answer_cnt = 0
    for i in a:
        count = 0;
        for j in a:
            j = j.replace('"', '')
            if i in j and len(i) > 1:
                count+=1;
                if answer_cnt < count:
                    answer_cnt = count
                    answers = i
    return answers

# %%
def head_lines(link):
#     <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/011/0003939046?ntype=RANKING">LG생건, 막말 논란 85년생 女 상무 대기발령</a>
        title = link.text
        link = 'https://news.naver.com'+link['href']            
        ord_id = link.split('&')[3] + '&' + link.split('&')[4]
        url = link
        
        browser.get(url)
        
        soup2 = BeautifulSoup(browser.page_source, 'lxml')
        
        categori = soup2.find('em' , {'class' : 'guide_categorization_item'})

        if categori and want_thing == categori.get_text():
            categoris = categori.get_text()
        elif '모두' in want_thing:
            categoris = categori.get_text()
        else:
            categoris = -1
        title = title.replace('"', "'")
        
        return title, press, categoris, link

# %%
def detail_table(link):
    soup = BeautifulSoup(browser.page_source, 'lxml')
    prev_height = browser.execute_script("return document.body.scrollHeight")
    while True:
        browser.execute_script("window.scrollTo(0, document.body.scrollHeight)")
        curr_height = browser.execute_script("return document.body.scrollHeight")    
        if curr_height == prev_height:    
            break
        prev_height = curr_height

    reporter = soup.find('div', {'class' : 'journalistcard_summary_name'})
    if reporter:
        reporter = reporter.text
    else:
        reporter = 'None'
    date = soup.find('span', {'class' : 't11'}).get_text()
    comment_cnt = 0
    try:
        comment_cnt = browser.find_element_by_css_selector('span.u_cbox_info_txt').text # 전체 댓글
    except:
        comment_cnt = browser.find_element_by_css_selector('em.simplecmt_num').text
        pass
    comment = int(comment_cnt.replace(',', ''))
    #comment_cnt = browser.find_element_by_css_selector('span.u_cbox_info_txt').text # 현재 댓글
    
    texts = soup.find('div', {'class' : '_article_body_contents'}).get_text()
    keyword = keyword_search(texts) # function
    
    return(reporter, date, comment, keyword)

# %%
conn = pymysql.connect(host='localhost', user='root', password='qwer1234', db='myungprj_db', charset='utf8')

# %%
conn

# %%
# 웹 스크래핑 부분

what_date = input('어느 일자의 기사들을 보시겠습니까 ("0720" 과 같이 입력하여 주십시오.)')

db = pymysql.connect(host='localhost', port=3306, user='root', passwd='qwer1234', db='myungprj_db', charset='utf8')
cursor = db.cursor() # cursor 클래스는 실제적으로 DB의 sql 구문을 실행시키고 조회된 결과를 가져옴
text = []

cursor.execute('drop table if exists headlines');
cursor.execute('drop table if exists detail_news');

sql = """
create table headlines
	(
	ord_id varchar(30) not null primary key,
    title varchar(300) not null,
    press varchar(100) not null,
    categori varchar(40) not null,
    url varchar(500) not null
    );
"""

cursor.execute(sql)

sql = """
create table detail_news
	(
    ord_id varchar(30) not null,
    reporter varchar(50) not null,
    date varchar(100),
    keyword varchar(20),
    comment_cnt int
    );
"""
cursor.execute(sql)
# Out:
# 어느 일자의 기사들을 보시겠습니까 ("0720" 과 같이 입력하여 주십시오.)0720
# 0

# %%
browser = webdriver.Chrome()
url = f'https://news.naver.com/main/ranking/popularDay.naver?date=2021{what_date}'

browser.get(url)

soup = BeautifulSoup(browser.page_source, 'lxml')

rankingnews = soup.find_all('div', {'class' : 'rankingnews_box'}) # 각 언론사 랭킹 박스 가져오기

# %%
want_thing = input('정치, 경제, 사회, 생활, 세계, IT 중에 보고싶은 카테고리를 입력하세요.(모든 카테고리를 희망한다면 "모두"를 입력하세요) : ')
what_press = input('어느 언론사의 기사들을 보시겠습니까. (모든 언론사를 원하신다면 "모두" 라고 입력하십시오)')
cnt = int(input('각 언론사에서 몇개의 기사들을 보시겠습니까. (1~5의 값을 입력해주세요)'))

for ranking in rankingnews:  # 각 언론사 랭킹 박스 리스트 for문
    press = ranking.find('strong', {'class' : 'rankingnews_name'}).text # 언론사 이름 ex) ytn, kbs, 서울경제 ...
    ranks = ranking.find_all('li') # 해당 언론사 리스트 랭킹
    count = 0
    for rank in ranks: # 해당 언론사 리스트 랭킹 for문
        if what_press not in press and what_press != '모두':
            continue

        count+=1
        if count > cnt:
            break;
        link = rank.find('a' , {'class' : "list_title nclicks('RBP.rnknws')"}) # 언론사 리스트 랭킹뉴스 링크
        
        if not link:
            continue
        elif link:
            print("링크는 >>",link)
            
            title = link.text
            print("title >>",title)
#             link = 'https://news.naver.com'+link['href']   
            link = link['href'] 
            print("link >>",link)
            url = link
            print("url >>",url)
            test = link.split('/')[5]
            print(link.split('/')[4]+test.split('?')[0])
            ord_id = link.split('/')[4]+test.split('?')[0]
            print("ord_id >>",ord_id)
            
            
            browser.get(url)
            
            soup2 = BeautifulSoup(browser.page_source, 'lxml')
            
            categori = soup2.find('em' , {'class' : 'guide_categorization_item'})
    
            if categori and want_thing == categori.get_text():
                categoris = categori.get_text()
            elif '모두' in want_thing:
                categoris = categori.get_text()
            else:
                categoris = -1
            title = title.replace('"', "'")
            
#             ord_id, title, press, categoris, link = head_lines(link) # function
#             title, press, categoris, link = head_lines(link) # function
            if categoris == -1:
                continue
            
            
            
            print("categoris",categoris)
# Out:
# 정치, 경제, 사회, 생활, 세계, IT 중에 보고싶은 카테고리를 입력하세요.(모든 카테고리를 희망한다면 "모두"를 입력하세요) : 정치
# 어느 언론사의 기사들을 보시겠습니까. (모든 언론사를 원하신다면 "모두" 라고 입력하십시오)모두
# 각 언론사에서 몇개의 기사들을 보시겠습니까. (1~5의 값을 입력해주세요)3
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/016/0001863618?ntype=RANKING">“마스크 안 쓴 일본인들, 중국 탁구대표팀과 기념촬영” 중국인들 분노</a>
# title >> “마스크 안 쓴 일본인들, 중국 탁구대표팀과 기념촬영” 중국인들 분노
# link >> https://n.news.naver.com/article/016/0001863618?ntype=RANKING
# url >> https://n.news.naver.com/article/016/0001863618?ntype=RANKING
# 0160001863618
# ord_id >> 0160001863618
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/016/0001864075?ntype=RANKING">“실제로 만나고 싶어요” 사람도 아닌데 ‘가상 인간’에 왜 빠질까</a>
# title >> “실제로 만나고 싶어요” 사람도 아닌데 ‘가상 인간’에 왜 빠질까
# link >> https://n.news.naver.com/article/016/0001864075?ntype=RANKING
# url >> https://n.news.naver.com/article/016/0001864075?ntype=RANKING
# 0160001864075
# ord_id >> 0160001864075
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/437/0000271591?ntype=RANKING">말려도 때렸다…눈 마주쳤다고 20분 동안 노인 폭행한 20대</a>
# title >> 말려도 때렸다…눈 마주쳤다고 20분 동안 노인 폭행한 20대
# link >> https://n.news.naver.com/article/437/0000271591?ntype=RANKING
# url >> https://n.news.naver.com/article/437/0000271591?ntype=RANKING
# 4370000271591
# ord_id >> 4370000271591
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/437/0000271581?ntype=RANKING">일본 네티즌들 "범 내려온다 현수막에 독도?…어이 없다"</a>
# title >> 일본 네티즌들 "범 내려온다 현수막에 독도?…어이 없다"
# link >> https://n.news.naver.com/article/437/0000271581?ntype=RANKING
# url >> https://n.news.naver.com/article/437/0000271581?ntype=RANKING
# 4370000271581
# ord_id >> 4370000271581
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/214/0001136864?ntype=RANKING">한·일 정상 만남 무산…"일본, 분위기 반전 노력 안 해"</a>
# title >> 한·일 정상 만남 무산…"일본, 분위기 반전 노력 안 해"
# link >> https://n.news.naver.com/article/214/0001136864?ntype=RANKING
# url >> https://n.news.naver.com/article/214/0001136864?ntype=RANKING
# 2140001136864
# ord_id >> 2140001136864
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/214/0001136865?ntype=RANKING">'히말라야 14좌 완등' 김홍빈 대장…하산 중 실종</a>
# title >> '히말라야 14좌 완등' 김홍빈 대장…하산 중 실종
# link >> https://n.news.naver.com/article/214/0001136865?ntype=RANKING
# url >> https://n.news.naver.com/article/214/0001136865?ntype=RANKING
# 2140001136865
# ord_id >> 2140001136865
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/214/0001137072?ntype=RANKING">감기 환자 9일 만에 105명 늘었는데도…"코로나 아니다"</a>
# title >> 감기 환자 9일 만에 105명 늘었는데도…"코로나 아니다"
# link >> https://n.news.naver.com/article/214/0001137072?ntype=RANKING
# url >> https://n.news.naver.com/article/214/0001137072?ntype=RANKING
# 2140001137072
# ord_id >> 2140001137072
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/055/0000908446?ntype=RANKING">[Pick] 부부 싸움 후 화풀이로 친딸 성폭행…30대男 징역 13년</a>
# title >> [Pick] 부부 싸움 후 화풀이로 친딸 성폭행…30대男 징역 13년
# link >> https://n.news.naver.com/article/055/0000908446?ntype=RANKING
# url >> https://n.news.naver.com/article/055/0000908446?ntype=RANKING
# 0550000908446
# ord_id >> 0550000908446
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/055/0000908514?ntype=RANKING">중학생 제자와 성관계한 전직 교사, 2심서 '감형' 왜?</a>
# title >> 중학생 제자와 성관계한 전직 교사, 2심서 '감형' 왜?
# link >> https://n.news.naver.com/article/055/0000908514?ntype=RANKING
# url >> https://n.news.naver.com/article/055/0000908514?ntype=RANKING
# 0550000908514
# ord_id >> 0550000908514
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/055/0000908338?ntype=RANKING">박지원 사위 "가방에 마약 든 줄 몰라"…투약은 인정</a>
# title >> 박지원 사위 "가방에 마약 든 줄 몰라"…투약은 인정
# link >> https://n.news.naver.com/article/055/0000908338?ntype=RANKING
# url >> https://n.news.naver.com/article/055/0000908338?ntype=RANKING
# 0550000908338
# ord_id >> 0550000908338
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/009/0004826303?ntype=RANKING">"입는건 자유라지만, 한뼘도 안 되는 옷 나만 불편한가?" 돌아온 배꼽티 와글와글</a>
# title >> "입는건 자유라지만, 한뼘도 안 되는 옷 나만 불편한가?" 돌아온 배꼽티 와글와글
# link >> https://n.news.naver.com/article/009/0004826303?ntype=RANKING
# url >> https://n.news.naver.com/article/009/0004826303?ntype=RANKING
# 0090004826303
# ord_id >> 0090004826303
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/009/0004826271?ntype=RANKING">'김굉필' 따라가니 대구가 달라보이네, 유네스코도 반한 그곳으로 역사 여행</a>
# title >> '김굉필' 따라가니 대구가 달라보이네, 유네스코도 반한 그곳으로 역사 여행
# link >> https://n.news.naver.com/article/009/0004826271?ntype=RANKING
# url >> https://n.news.naver.com/article/009/0004826271?ntype=RANKING
# 0090004826271
# ord_id >> 0090004826271
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/009/0004826253?ntype=RANKING">6300만원 같은 가격…국산차 세금, 수입차보다 100만원 많다</a>
# title >> 6300만원 같은 가격…국산차 세금, 수입차보다 100만원 많다
# link >> https://n.news.naver.com/article/009/0004826253?ntype=RANKING
# url >> https://n.news.naver.com/article/009/0004826253?ntype=RANKING
# 0090004826253
# ord_id >> 0090004826253
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/047/0002320443?ntype=RANKING">처치 곤란 아이스팩, 이렇게 재활용했더니 감동이네요</a>
# title >> 처치 곤란 아이스팩, 이렇게 재활용했더니 감동이네요
# link >> https://n.news.naver.com/article/047/0002320443?ntype=RANKING
# url >> https://n.news.naver.com/article/047/0002320443?ntype=RANKING
# 0470002320443
# ord_id >> 0470002320443
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/047/0002320449?ntype=RANKING">항암식품이라기에... 몇 달간 '독'을 먹었습니다 [송성영의 암과 함께 살아가기]</a>
# title >> 항암식품이라기에... 몇 달간 '독'을 먹었습니다 [송성영의 암과 함께 살아가기]
# link >> https://n.news.naver.com/article/047/0002320449?ntype=RANKING
# url >> https://n.news.naver.com/article/047/0002320449?ntype=RANKING
# 0470002320449
# ord_id >> 0470002320449
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/047/0002320409?ntype=RANKING">대구서 대면예배 강행 황교안... 기자들도 '손절'</a>
# title >> 대구서 대면예배 강행 황교안... 기자들도 '손절'
# link >> https://n.news.naver.com/article/047/0002320409?ntype=RANKING
# url >> https://n.news.naver.com/article/047/0002320409?ntype=RANKING
# 0470002320409
# ord_id >> 0470002320409
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/015/0004580686?ntype=RANKING">한 달 만에 1만대 '돌풍'…인도서 대박난 현대차 SUV [車 UP &amp; DOWN]</a>
# title >> 한 달 만에 1만대 '돌풍'…인도서 대박난 현대차 SUV [車 UP & DOWN]
# link >> https://n.news.naver.com/article/015/0004580686?ntype=RANKING
# url >> https://n.news.naver.com/article/015/0004580686?ntype=RANKING
# 0150004580686
# ord_id >> 0150004580686
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/015/0004580654?ntype=RANKING">"집값 20% 폭락한다면…" 한국은행의 섬뜩한 경고 [김익환의 BOK워치]</a>
# title >> "집값 20% 폭락한다면…" 한국은행의 섬뜩한 경고 [김익환의 BOK워치]
# link >> https://n.news.naver.com/article/015/0004580654?ntype=RANKING
# url >> https://n.news.naver.com/article/015/0004580654?ntype=RANKING
# 0150004580654
# ord_id >> 0150004580654
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/028/0002553220?ntype=RANKING">부산 거리두기 3단계 격상…“주말까지 안 잡히면 4단계로”</a>
# title >> 부산 거리두기 3단계 격상…“주말까지 안 잡히면 4단계로”
# link >> https://n.news.naver.com/article/028/0002553220?ntype=RANKING
# url >> https://n.news.naver.com/article/028/0002553220?ntype=RANKING
# 0280002553220
# ord_id >> 0280002553220
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/028/0002553203?ntype=RANKING">쿠팡물류센터는 ‘철판 열돔’…“열사병으로 쓰러질 판”</a>
# title >> 쿠팡물류센터는 ‘철판 열돔’…“열사병으로 쓰러질 판”
# link >> https://n.news.naver.com/article/028/0002553203?ntype=RANKING
# url >> https://n.news.naver.com/article/028/0002553203?ntype=RANKING
# 0280002553203
# ord_id >> 0280002553203
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/028/0002553340?ntype=RANKING">‘댐 붕괴 우려 경고’ 하루 전 “집에 있으라”…독일 정부, 비판 직면</a>
# title >> ‘댐 붕괴 우려 경고’ 하루 전 “집에 있으라”…독일 정부, 비판 직면
# link >> https://n.news.naver.com/article/028/0002553340?ntype=RANKING
# url >> https://n.news.naver.com/article/028/0002553340?ntype=RANKING
# 0280002553340
# ord_id >> 0280002553340
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/001/0012535673?ntype=RANKING">[르포] 지하철서 '노 마스크'…일 20만명 확진 전망에도 규제 푼 영국</a>
# title >> [르포] 지하철서 '노 마스크'…일 20만명 확진 전망에도 규제 푼 영국
# link >> https://n.news.naver.com/article/001/0012535673?ntype=RANKING
# url >> https://n.news.naver.com/article/001/0012535673?ntype=RANKING
# 0010012535673
# ord_id >> 0010012535673
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/001/0012537866?ntype=RANKING">11시간만에 구조된 김홍빈, 의식 있었다…구조중 줄 끊기며 추락</a>
# title >> 11시간만에 구조된 김홍빈, 의식 있었다…구조중 줄 끊기며 추락
# link >> https://n.news.naver.com/article/001/0012537866?ntype=RANKING
# url >> https://n.news.naver.com/article/001/0012537866?ntype=RANKING
# 0010012537866
# ord_id >> 0010012537866
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/001/0012536588?ntype=RANKING">트로트 가수 김호중, 자택 앞 시비로 경찰 신고</a>
# title >> 트로트 가수 김호중, 자택 앞 시비로 경찰 신고
# link >> https://n.news.naver.com/article/001/0012536588?ntype=RANKING
# url >> https://n.news.naver.com/article/001/0012536588?ntype=RANKING
# 0010012536588
# ord_id >> 0010012536588
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/018/0004989285?ntype=RANKING">[단독]밤새 수십시간 줄 선 사전예약, '대기 무력화' 기능 나왔었다</a>
# title >> [단독]밤새 수십시간 줄 선 사전예약, '대기 무력화' 기능 나왔었다
# link >> https://n.news.naver.com/article/018/0004989285?ntype=RANKING
# url >> https://n.news.naver.com/article/018/0004989285?ntype=RANKING
# 0180004989285
# ord_id >> 0180004989285
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/018/0004989393?ntype=RANKING">호텔 술판 NC 박민우 첫 조사…확진자 5명은 격리해제 후 소환</a>
# title >> 호텔 술판 NC 박민우 첫 조사…확진자 5명은 격리해제 후 소환
# link >> https://n.news.naver.com/article/018/0004989393?ntype=RANKING
# url >> https://n.news.naver.com/article/018/0004989393?ntype=RANKING
# 0180004989393
# ord_id >> 0180004989393
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/018/0004990029?ntype=RANKING">1등 하고도 여자라서 못 간 우주…60년만에 꿈 이룬 82세 월리 펑크</a>
# title >> 1등 하고도 여자라서 못 간 우주…60년만에 꿈 이룬 82세 월리 펑크
# link >> https://n.news.naver.com/article/018/0004990029?ntype=RANKING
# url >> https://n.news.naver.com/article/018/0004990029?ntype=RANKING
# 0180004990029
# ord_id >> 0180004990029
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/215/0000972908?ntype=RANKING">"한국, 이미 중국땅이다"...무섭게 사들이는 붉은자본</a>
# title >> "한국, 이미 중국땅이다"...무섭게 사들이는 붉은자본
# link >> https://n.news.naver.com/article/215/0000972908?ntype=RANKING
# url >> https://n.news.naver.com/article/215/0000972908?ntype=RANKING
# 2150000972908
# ord_id >> 2150000972908
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/215/0000972675?ntype=RANKING">"드디어 올가을 손에쥔다"…아빠들 가슴에 불지핀 `대원미디어` [박해린의 뉴스&amp;마켓]</a>
# title >> "드디어 올가을 손에쥔다"…아빠들 가슴에 불지핀 `대원미디어` [박해린의 뉴스&마켓]
# link >> https://n.news.naver.com/article/215/0000972675?ntype=RANKING
# url >> https://n.news.naver.com/article/215/0000972675?ntype=RANKING
# 2150000972675
# ord_id >> 2150000972675
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/215/0000972756?ntype=RANKING">사전계약만 2만2천대..."덩치 키웠더니 인기"</a>
# title >> 사전계약만 2만2천대..."덩치 키웠더니 인기"
# link >> https://n.news.naver.com/article/215/0000972756?ntype=RANKING
# url >> https://n.news.naver.com/article/215/0000972756?ntype=RANKING
# 2150000972756
# ord_id >> 2150000972756
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/023/0003628008?ntype=RANKING">[송의달이 만난 사람] “중국에 겁 먹고 나약한 한국 정치인들…어렵게 쟁취한 독립 지킬수 있나”</a>
# title >> [송의달이 만난 사람] “중국에 겁 먹고 나약한 한국 정치인들…어렵게 쟁취한 독립 지킬수 있나”
# link >> https://n.news.naver.com/article/023/0003628008?ntype=RANKING
# url >> https://n.news.naver.com/article/023/0003628008?ntype=RANKING
# 0230003628008
# ord_id >> 0230003628008
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/023/0003627893?ntype=RANKING">임성한 드라마, 막장 아니라 100분 토론이었나</a>
# title >> 임성한 드라마, 막장 아니라 100분 토론이었나
# link >> https://n.news.naver.com/article/023/0003627893?ntype=RANKING
# url >> https://n.news.naver.com/article/023/0003627893?ntype=RANKING
# 0230003627893
# ord_id >> 0230003627893
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/023/0003627911?ntype=RANKING">1만원 간짜장, 배달·수수료 4500원… 식당 ‘한건 배달’의 현실</a>
# title >> 1만원 간짜장, 배달·수수료 4500원… 식당 ‘한건 배달’의 현실
# link >> https://n.news.naver.com/article/023/0003627911?ntype=RANKING
# url >> https://n.news.naver.com/article/023/0003627911?ntype=RANKING
# 0230003627911
# ord_id >> 0230003627911
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/052/0001616368?ntype=RANKING">'히말라야 14좌 완등' 김홍빈 대장 실종...오늘 첫 헬기 수색</a>
# title >> '히말라야 14좌 완등' 김홍빈 대장 실종...오늘 첫 헬기 수색
# link >> https://n.news.naver.com/article/052/0001616368?ntype=RANKING
# url >> https://n.news.naver.com/article/052/0001616368?ntype=RANKING
# 0520001616368
# ord_id >> 0520001616368
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/469/0000618507?ntype=RANKING">"한국 대표팀에 왜 후쿠시마산 강요하나" 도시락 공수, 의외의 日 반응</a>
# title >> "한국 대표팀에 왜 후쿠시마산 강요하나" 도시락 공수, 의외의 日 반응
# link >> https://n.news.naver.com/article/469/0000618507?ntype=RANKING
# url >> https://n.news.naver.com/article/469/0000618507?ntype=RANKING
# 4690000618507
# ord_id >> 4690000618507
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/469/0000618317?ntype=RANKING">성관계 방지용? 놀림거리 된 日 올림픽 '골판지 침대'</a>
# title >> 성관계 방지용? 놀림거리 된 日 올림픽 '골판지 침대'
# link >> https://n.news.naver.com/article/469/0000618317?ntype=RANKING
# url >> https://n.news.naver.com/article/469/0000618317?ntype=RANKING
# 4690000618317
# ord_id >> 4690000618317
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/469/0000618289?ntype=RANKING">'블랙아웃' 우려에... 가정에서 에어컨 많이 틀면 정말 큰일날까</a>
# title >> '블랙아웃' 우려에... 가정에서 에어컨 많이 틀면 정말 큰일날까
# link >> https://n.news.naver.com/article/469/0000618289?ntype=RANKING
# url >> https://n.news.naver.com/article/469/0000618289?ntype=RANKING
# 4690000618289
# ord_id >> 4690000618289
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/081/0003202730?ntype=RANKING">‘이순신’ 대신 ‘범 내려온다’ 걸자…日누리꾼 “어이없다”는데</a>
# title >> ‘이순신’ 대신 ‘범 내려온다’ 걸자…日누리꾼 “어이없다”는데
# link >> https://n.news.naver.com/article/081/0003202730?ntype=RANKING
# url >> https://n.news.naver.com/article/081/0003202730?ntype=RANKING
# 0810003202730
# ord_id >> 0810003202730
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/081/0003202791?ntype=RANKING">“벗은 몸 보고 데이트 상대 선택해요”…시즌7까지 나온 英방송</a>
# title >> “벗은 몸 보고 데이트 상대 선택해요”…시즌7까지 나온 英방송
# link >> https://n.news.naver.com/article/081/0003202791?ntype=RANKING
# url >> https://n.news.naver.com/article/081/0003202791?ntype=RANKING
# 0810003202791
# ord_id >> 0810003202791
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/081/0003202797?ntype=RANKING">소상공인 지원금 대폭 증액… 최대 1000만원 넘게 받을 듯</a>
# title >> 소상공인 지원금 대폭 증액… 최대 1000만원 넘게 받을 듯
# link >> https://n.news.naver.com/article/081/0003202797?ntype=RANKING
# url >> https://n.news.naver.com/article/081/0003202797?ntype=RANKING
# 0810003202797
# ord_id >> 0810003202797
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/056/0011086304?ntype=RANKING">제주 중학생 살해 피의자 검거…“범행동기 나중에 말하겠다. 죄송하다”</a>
# title >> 제주 중학생 살해 피의자 검거…“범행동기 나중에 말하겠다. 죄송하다”
# link >> https://n.news.naver.com/article/056/0011086304?ntype=RANKING
# url >> https://n.news.naver.com/article/056/0011086304?ntype=RANKING
# 0560011086304
# ord_id >> 0560011086304
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/032/0003086560?ntype=RANKING">"밤 지샜다. 많이 춥다" 조난 김홍빈 대장 마지막 통화</a>
# title >> "밤 지샜다. 많이 춥다" 조난 김홍빈 대장 마지막 통화
# link >> https://n.news.naver.com/article/032/0003086560?ntype=RANKING
# url >> https://n.news.naver.com/article/032/0003086560?ntype=RANKING
# 0320003086560
# ord_id >> 0320003086560
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/032/0003086564?ntype=RANKING">부산 하루 확진자 100명 육박···거리두기 3단계 격상</a>
# title >> 부산 하루 확진자 100명 육박···거리두기 3단계 격상
# link >> https://n.news.naver.com/article/032/0003086564?ntype=RANKING
# url >> https://n.news.naver.com/article/032/0003086564?ntype=RANKING
# 0320003086564
# ord_id >> 0320003086564
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/293/0000035623?ntype=RANKING">애플 '맥세이프 배터리팩' 해외 후기..."에어팟도 충전 가능해"</a>
# title >> 애플 '맥세이프 배터리팩' 해외 후기..."에어팟도 충전 가능해"
# link >> https://n.news.naver.com/article/293/0000035623?ntype=RANKING
# url >> https://n.news.naver.com/article/293/0000035623?ntype=RANKING
# 2930000035623
# ord_id >> 2930000035623
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/293/0000035632?ntype=RANKING">[EV·수소 밸류체인]두산중공업, 美 소형원전 제작사 뉴스케일파워 추가 투자</a>
# title >> [EV·수소 밸류체인]두산중공업, 美 소형원전 제작사 뉴스케일파워 추가 투자
# link >> https://n.news.naver.com/article/293/0000035632?ntype=RANKING
# url >> https://n.news.naver.com/article/293/0000035632?ntype=RANKING
# 2930000035632
# ord_id >> 2930000035632
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/293/0000035624?ntype=RANKING">비트코인 채굴 난이도 5월 대비 45% 하락...중국 채굴 업자들 '미국행' 준비</a>
# title >> 비트코인 채굴 난이도 5월 대비 45% 하락...중국 채굴 업자들 '미국행' 준비
# link >> https://n.news.naver.com/article/293/0000035624?ntype=RANKING
# url >> https://n.news.naver.com/article/293/0000035624?ntype=RANKING
# 2930000035624
# ord_id >> 2930000035624
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/057/0001594090?ntype=RANKING">윤석열 "골프 접대 사실 없다"…최재형, '대역전극' 오세훈 만나</a>
# title >> 윤석열 "골프 접대 사실 없다"…최재형, '대역전극' 오세훈 만나
# link >> https://n.news.naver.com/article/057/0001594090?ntype=RANKING
# url >> https://n.news.naver.com/article/057/0001594090?ntype=RANKING
# 0570001594090
# ord_id >> 0570001594090
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/057/0001594184?ntype=RANKING">벗은 몸 보고 데이트 상대 고르는 방송 프로그램에 '항의 폭주'</a>
# title >> 벗은 몸 보고 데이트 상대 고르는 방송 프로그램에 '항의 폭주'
# link >> https://n.news.naver.com/article/057/0001594184?ntype=RANKING
# url >> https://n.news.naver.com/article/057/0001594184?ntype=RANKING
# 0570001594184
# ord_id >> 0570001594184
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/057/0001594071?ntype=RANKING">'열 손가락 없는' 김홍빈 대장, 하산 중 실종…"사태 파악 중"</a>
# title >> '열 손가락 없는' 김홍빈 대장, 하산 중 실종…"사태 파악 중"
# link >> https://n.news.naver.com/article/057/0001594071?ntype=RANKING
# url >> https://n.news.naver.com/article/057/0001594071?ntype=RANKING
# 0570001594071
# ord_id >> 0570001594071
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/092/0002228191?ntype=RANKING">애플 "주 3회 출근하라"...직원들 원격근무 통제에 반발</a>
# title >> 애플 "주 3회 출근하라"...직원들 원격근무 통제에 반발
# link >> https://n.news.naver.com/article/092/0002228191?ntype=RANKING
# url >> https://n.news.naver.com/article/092/0002228191?ntype=RANKING
# 0920002228191
# ord_id >> 0920002228191
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/092/0002228201?ntype=RANKING">기아, 신형 스포티지 출시…2442만~3593만원</a>
# title >> 기아, 신형 스포티지 출시…2442만~3593만원
# link >> https://n.news.naver.com/article/092/0002228201?ntype=RANKING
# url >> https://n.news.naver.com/article/092/0002228201?ntype=RANKING
# 0920002228201
# ord_id >> 0920002228201
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/092/0002228192?ntype=RANKING">유튜브 쇼츠, ‘BTS 댄스 챌린지’ 진행</a>
# title >> 유튜브 쇼츠, ‘BTS 댄스 챌린지’ 진행
# link >> https://n.news.naver.com/article/092/0002228192?ntype=RANKING
# url >> https://n.news.naver.com/article/092/0002228192?ntype=RANKING
# 0920002228192
# ord_id >> 0920002228192
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/014/0004677550?ntype=RANKING">길가던 여성 3일간 감금 성폭행 한 '수유동 악마' 법정선 "선처 좀"</a>
# title >> 길가던 여성 3일간 감금 성폭행 한 '수유동 악마' 법정선 "선처 좀"
# link >> https://n.news.naver.com/article/014/0004677550?ntype=RANKING
# url >> https://n.news.naver.com/article/014/0004677550?ntype=RANKING
# 0140004677550
# ord_id >> 0140004677550
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/014/0004677541?ntype=RANKING">부부 싸움만 하면 초등생 친딸에 화풀이 성폭행 한 30대 남성</a>
# title >> 부부 싸움만 하면 초등생 친딸에 화풀이 성폭행 한 30대 남성
# link >> https://n.news.naver.com/article/014/0004677541?ntype=RANKING
# url >> https://n.news.naver.com/article/014/0004677541?ntype=RANKING
# 0140004677541
# ord_id >> 0140004677541
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/014/0004677864?ntype=RANKING">'트바로티' 김호중 대체복무 중 폭행 혐의 경찰 조사받는다</a>
# title >> '트바로티' 김호중 대체복무 중 폭행 혐의 경찰 조사받는다
# link >> https://n.news.naver.com/article/014/0004677864?ntype=RANKING
# url >> https://n.news.naver.com/article/014/0004677864?ntype=RANKING
# 0140004677864
# ord_id >> 0140004677864
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/138/0002107111?ntype=RANKING">하락장서 5배 오른 블록체인 게임 토큰…왜 ‘엑시인피니티’ 가 인기일까</a>
# title >> 하락장서 5배 오른 블록체인 게임 토큰…왜 ‘엑시인피니티’ 가 인기일까
# link >> https://n.news.naver.com/article/138/0002107111?ntype=RANKING
# url >> https://n.news.naver.com/article/138/0002107111?ntype=RANKING
# 1380002107111
# ord_id >> 1380002107111
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/138/0002107146?ntype=RANKING">흔들림 없는 '오딘'…리니지 따돌리고 블소2 견뎌낼까</a>
# title >> 흔들림 없는 '오딘'…리니지 따돌리고 블소2 견뎌낼까
# link >> https://n.news.naver.com/article/138/0002107146?ntype=RANKING
# url >> https://n.news.naver.com/article/138/0002107146?ntype=RANKING
# 1380002107146
# ord_id >> 1380002107146
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/007/0000006839?ntype=RANKING">‘남편의 폭력’ 전염병만큼 긴박한 개입과 대책 필요</a>
# title >> ‘남편의 폭력’ 전염병만큼 긴박한 개입과 대책 필요
# link >> https://n.news.naver.com/article/007/0000006839?ntype=RANKING
# url >> https://n.news.naver.com/article/007/0000006839?ntype=RANKING
# 0070000006839
# ord_id >> 0070000006839
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/007/0000006838?ntype=RANKING">코로나 여파, 궁지에 몰린 십대여성 ‘성착취’ 심각</a>
# title >> 코로나 여파, 궁지에 몰린 십대여성 ‘성착취’ 심각
# link >> https://n.news.naver.com/article/007/0000006838?ntype=RANKING
# url >> https://n.news.naver.com/article/007/0000006838?ntype=RANKING
# 0070000006838
# ord_id >> 0070000006838
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/007/0000006840?ntype=RANKING">디지털 성범죄를 겪고 ‘살아남은 자’의 목소리</a>
# title >> 디지털 성범죄를 겪고 ‘살아남은 자’의 목소리
# link >> https://n.news.naver.com/article/007/0000006840?ntype=RANKING
# url >> https://n.news.naver.com/article/007/0000006840?ntype=RANKING
# 0070000006840
# ord_id >> 0070000006840
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/079/0003530192?ntype=RANKING">여수 한재사거리 자동차 운반트럭 다중추돌…12명 사상(종합)</a>
# title >> 여수 한재사거리 자동차 운반트럭 다중추돌…12명 사상(종합)
# link >> https://n.news.naver.com/article/079/0003530192?ntype=RANKING
# url >> https://n.news.naver.com/article/079/0003530192?ntype=RANKING
# 0790003530192
# ord_id >> 0790003530192
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/079/0003530123?ntype=RANKING">바닷가에서 익은 조개, 솟구친 불구름…뜨거워진 지구[이슈시개]</a>
# title >> 바닷가에서 익은 조개, 솟구친 불구름…뜨거워진 지구[이슈시개]
# link >> https://n.news.naver.com/article/079/0003530123?ntype=RANKING
# url >> https://n.news.naver.com/article/079/0003530123?ntype=RANKING
# 0790003530123
# ord_id >> 0790003530123
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/079/0003530243?ntype=RANKING">[영상]與 "나라 팔아먹은 친일파"…野김석기 발언 파장[이슈시개]</a>
# title >> [영상]與 "나라 팔아먹은 친일파"…野김석기 발언 파장[이슈시개]
# link >> https://n.news.naver.com/article/079/0003530243?ntype=RANKING
# url >> https://n.news.naver.com/article/079/0003530243?ntype=RANKING
# 0790003530243
# ord_id >> 0790003530243
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/296/0000050897?ntype=RANKING">여름철 뱃살 빼는 데 효과적인 방법 4</a>
# title >> 여름철 뱃살 빼는 데 효과적인 방법 4
# link >> https://n.news.naver.com/article/296/0000050897?ntype=RANKING
# url >> https://n.news.naver.com/article/296/0000050897?ntype=RANKING
# 2960000050897
# ord_id >> 2960000050897
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/296/0000050895?ntype=RANKING">여름철 냄새나는 빨래…“세탁기도 살균해야”</a>
# title >> 여름철 냄새나는 빨래…“세탁기도 살균해야”
# link >> https://n.news.naver.com/article/296/0000050895?ntype=RANKING
# url >> https://n.news.naver.com/article/296/0000050895?ntype=RANKING
# 2960000050895
# ord_id >> 2960000050895
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/031/0000611871?ntype=RANKING">구미 50대 경찰관, AZ·화이자 백신 교차접종후 사흘 만에 숨져</a>
# title >> 구미 50대 경찰관, AZ·화이자 백신 교차접종후 사흘 만에 숨져
# link >> https://n.news.naver.com/article/031/0000611871?ntype=RANKING
# url >> https://n.news.naver.com/article/031/0000611871?ntype=RANKING
# 0310000611871
# ord_id >> 0310000611871
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/031/0000611877?ntype=RANKING">김호중, 공사 업체 관계자와 시비로 경찰조사…"폭행 없었다"</a>
# title >> 김호중, 공사 업체 관계자와 시비로 경찰조사…"폭행 없었다"
# ...
# title >> 민주노총 "코로나 재확산은 정부 탓…책임 돌리지 말라"
# link >> https://n.news.naver.com/article/586/0000026958?ntype=RANKING
# url >> https://n.news.naver.com/article/586/0000026958?ntype=RANKING
# 5860000026958
# ord_id >> 5860000026958
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/586/0000026963?ntype=RANKING">코로나19보다 무서운 막무가내식 재난지원금 지급</a>
# title >> 코로나19보다 무서운 막무가내식 재난지원금 지급
# link >> https://n.news.naver.com/article/586/0000026963?ntype=RANKING
# url >> https://n.news.naver.com/article/586/0000026963?ntype=RANKING
# 5860000026963
# ord_id >> 5860000026963
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/586/0000026998?ntype=RANKING">文대통령 방일 떠들며 '이중태도' 취했던 日…정상회담 무산된 이유 셋</a>
# title >> 文대통령 방일 떠들며 '이중태도' 취했던 日…정상회담 무산된 이유 셋
# link >> https://n.news.naver.com/article/586/0000026998?ntype=RANKING
# url >> https://n.news.naver.com/article/586/0000026998?ntype=RANKING
# 5860000026998
# ord_id >> 5860000026998
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/021/0002478922?ntype=RANKING">‘블랙아웃’ 우려 커지자…낮시간 냉방 28도에 맞추라는 정부</a>
# title >> ‘블랙아웃’ 우려 커지자…낮시간 냉방 28도에 맞추라는 정부
# link >> https://n.news.naver.com/article/021/0002478922?ntype=RANKING
# url >> https://n.news.naver.com/article/021/0002478922?ntype=RANKING
# 0210002478922
# ord_id >> 0210002478922
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/021/0002478948?ntype=RANKING">BTS 뛰어넘은 BTS, ‘버터’→‘퍼미션 투 댄스’ 빌보드 1위 배턴터치</a>
# title >> BTS 뛰어넘은 BTS, ‘버터’→‘퍼미션 투 댄스’ 빌보드 1위 배턴터치
# link >> https://n.news.naver.com/article/021/0002478948?ntype=RANKING
# url >> https://n.news.naver.com/article/021/0002478948?ntype=RANKING
# 0210002478948
# ord_id >> 0210002478948
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/021/0002478901?ntype=RANKING">文대통령 “軍 안이한 대처”… 사과 없이 질책</a>
# title >> 文대통령 “軍 안이한 대처”… 사과 없이 질책
# link >> https://n.news.naver.com/article/021/0002478901?ntype=RANKING
# url >> https://n.news.naver.com/article/021/0002478901?ntype=RANKING
# 0210002478901
# ord_id >> 0210002478901
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/050/0000058112?ntype=RANKING">셀트리온 코로나 치료제 인도네시아에서 승인</a>
# title >> 셀트리온 코로나 치료제 인도네시아에서 승인
# link >> https://n.news.naver.com/article/050/0000058112?ntype=RANKING
# url >> https://n.news.naver.com/article/050/0000058112?ntype=RANKING
# 0500000058112
# ord_id >> 0500000058112
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/050/0000058108?ntype=RANKING">文 정부의 과도한 부동산 정책, 매매가 이어 전셋값 상승까지 야기[아기곰의 부동산 산책]</a>
# title >> 文 정부의 과도한 부동산 정책, 매매가 이어 전셋값 상승까지 야기[아기곰의 부동산 산책]
# link >> https://n.news.naver.com/article/050/0000058108?ntype=RANKING
# url >> https://n.news.naver.com/article/050/0000058108?ntype=RANKING
# 0500000058108
# ord_id >> 0500000058108
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/050/0000058105?ntype=RANKING">흔들리는 쿠팡, 골목길 로켓배송으로 반격 개시</a>
# title >> 흔들리는 쿠팡, 골목길 로켓배송으로 반격 개시
# link >> https://n.news.naver.com/article/050/0000058105?ntype=RANKING
# url >> https://n.news.naver.com/article/050/0000058105?ntype=RANKING
# 0500000058105
# ord_id >> 0500000058105
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/629/0000095831?ntype=RANKING">[단독] '성추행 여배우 명예훼손' 조덕제, 징역 3년 구형...檢 "2차 가해 여전"</a>
# title >> [단독] '성추행 여배우 명예훼손' 조덕제, 징역 3년 구형...檢 "2차 가해 여전"
# link >> https://n.news.naver.com/article/629/0000095831?ntype=RANKING
# url >> https://n.news.naver.com/article/629/0000095831?ntype=RANKING
# 6290000095831
# ord_id >> 6290000095831
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/629/0000095759?ntype=RANKING">오늘밤 8시부터 53~54세 백신 예약…50대 모더나+화이자로</a>
# title >> 오늘밤 8시부터 53~54세 백신 예약…50대 모더나+화이자로
# link >> https://n.news.naver.com/article/629/0000095759?ntype=RANKING
# url >> https://n.news.naver.com/article/629/0000095759?ntype=RANKING
# 6290000095759
# ord_id >> 6290000095759
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/629/0000095817?ntype=RANKING">코로나 백신 접종 사전예약시스템 또 먹통… 53~54세 예약 차질</a>
# title >> 코로나 백신 접종 사전예약시스템 또 먹통… 53~54세 예약 차질
# link >> https://n.news.naver.com/article/629/0000095817?ntype=RANKING
# url >> https://n.news.naver.com/article/629/0000095817?ntype=RANKING
# 6290000095817
# ord_id >> 6290000095817
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/088/0000713088?ntype=RANKING">[속보] 여수서 탁송차량이 횡단보도 덮쳐 3명 사망·9명 부상</a>
# title >> [속보] 여수서 탁송차량이 횡단보도 덮쳐 3명 사망·9명 부상
# link >> https://n.news.naver.com/article/088/0000713088?ntype=RANKING
# url >> https://n.news.naver.com/article/088/0000713088?ntype=RANKING
# 0880000713088
# ord_id >> 0880000713088
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/088/0000713174?ntype=RANKING">[속보] 전국 오후 6시 1442명 확진 "최다 기록 나온 13일 같은 시각 1288명 대비 154명 증가 "</a>
# title >> [속보] 전국 오후 6시 1442명 확진 "최다 기록 나온 13일 같은 시각 1288명 대비 154명 증가 "
# link >> https://n.news.naver.com/article/088/0000713174?ntype=RANKING
# url >> https://n.news.naver.com/article/088/0000713174?ntype=RANKING
# 0880000713174
# ord_id >> 0880000713174
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article
a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/374/0000251636?ntype=RANKING">전력수급 비상에 결국 재가동…원전 3기 조기 ‘구원등판’</a>
# title >> 전력수급 비상에 결국 재가동…원전 3기 조기 ‘구원등판’
# link >> https://n.news.naver.com/article/374/0000251636?ntype=RANKING
# url >> https://n.news.naver.com/article/374/0000251636?ntype=RANKING
# 3740000251636
# ord_id >> 3740000251636
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/374/0000251506?ntype=RANKING">고가 전략 포기?…삼성, ‘초’저가 폴더블 내놓는 이유는</a>
# title >> 고가 전략 포기?…삼성, ‘초’저가 폴더블 내놓는 이유는
# link >> https://n.news.naver.com/article/374/0000251506?ntype=RANKING
# url >> https://n.news.naver.com/article/374/0000251506?ntype=RANKING
# 3740000251506
# ord_id >> 3740000251506
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/243/0000014623?ntype=RANKING">[단독] 셀트리온, 삼바에 코로나 치료제 CMO 맡긴다</a>
# title >> [단독] 셀트리온, 삼바에 코로나 치료제 CMO 맡긴다
# link >> https://n.news.naver.com/article/243/0000014623?ntype=RANKING
# url >> https://n.news.naver.com/article/243/0000014623?ntype=RANKING
# 2430000014623
# ord_id >> 2430000014623
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/243/0000014610?ntype=RANKING">폭염에 ‘열돔’까지 겹친다…이번 주 8년 만에 비상단계 가능성</a>
# title >> 폭염에 ‘열돔’까지 겹친다…이번 주 8년 만에 비상단계 가능성
# link >> https://n.news.naver.com/article/243/0000014610?ntype=RANKING
# url >> https://n.news.naver.com/article/243/0000014610?ntype=RANKING
# 2430000014610
# ord_id >> 2430000014610
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/243/0000014624?ntype=RANKING">3만달러 깨진 비트코인… 상승세 끝났나</a>
# title >> 3만달러 깨진 비트코인… 상승세 끝났나
# link >> https://n.news.naver.com/article/243/0000014624?ntype=RANKING
# url >> https://n.news.naver.com/article/243/0000014624?ntype=RANKING
# 2430000014624
# ord_id >> 2430000014624
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/082/0001107996?ntype=RANKING">부산 확진자 100명 안팎…21일 0시부터 거리 두기 3단계(종합)</a>
# title >> 부산 확진자 100명 안팎…21일 0시부터 거리 두기 3단계(종합)
# link >> https://n.news.naver.com/article/082/0001107996?ntype=RANKING
# url >> https://n.news.naver.com/article/082/0001107996?ntype=RANKING
# 0820001107996
# ord_id >> 0820001107996
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/082/0001108062?ntype=RANKING">[속보] 인원 관계없이 해운대·송정 해수욕장 야간 음주·취식 금지</a>
# title >> [속보] 인원 관계없이 해운대·송정 해수욕장 야간 음주·취식 금지
# link >> https://n.news.naver.com/article/082/0001108062?ntype=RANKING
# url >> https://n.news.naver.com/article/082/0001108062?ntype=RANKING
# 0820001108062
# ord_id >> 0820001108062
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/082/0001108212?ntype=RANKING">[단독] 양산부산대병원 간호사 코로나 확진… 방역 초비상</a>
# title >> [단독] 양산부산대병원 간호사 코로나 확진… 방역 초비상
# link >> https://n.news.naver.com/article/082/0001108212?ntype=RANKING
# url >> https://n.news.naver.com/article/082/0001108212?ntype=RANKING
# 0820001108212
# ord_id >> 0820001108212
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/607/0000000825?ntype=RANKING">윤우진 입 열다① "윤석열이 변호사 소개했다"</a>
# title >> 윤우진 입 열다① "윤석열이 변호사 소개했다"
# link >> https://n.news.naver.com/article/607/0000000825?ntype=RANKING
# url >> https://n.news.naver.com/article/607/0000000825?ntype=RANKING
# 6070000000825
# ord_id >> 6070000000825
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/607/0000000823?ntype=RANKING">GTX와 기울어진 아파트, 도심 터널의 잠재적 위험</a>
# title >> GTX와 기울어진 아파트, 도심 터널의 잠재적 위험
# link >> https://n.news.naver.com/article/607/0000000823?ntype=RANKING
# url >> https://n.news.naver.com/article/607/0000000823?ntype=RANKING
# 6070000000823
# ord_id >> 6070000000823
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/607/0000000821?ntype=RANKING">[변화] 공수처, 김형준-박수종 뇌물 의혹 수사 착수</a>
# title >> [변화] 공수처, 김형준-박수종 뇌물 의혹 수사 착수
# link >> https://n.news.naver.com/article/607/0000000821?ntype=RANKING
# url >> https://n.news.naver.com/article/607/0000000821?ntype=RANKING
# 6070000000821
# ord_id >> 6070000000821
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/123/0002250679?ntype=RANKING">수도권 '55~59세' 화이자 백신 접종…'53~54세' 예약률 53.9%</a>
# title >> 수도권 '55~59세' 화이자 백신 접종…'53~54세' 예약률 53.9%
# link >> https://n.news.naver.com/article/123/0002250679?ntype=RANKING
# url >> https://n.news.naver.com/article/123/0002250679?ntype=RANKING
# 1230002250679
# ord_id >> 1230002250679
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/123/0002250663?ntype=RANKING">바흐 IOC위원장 "얼마나 복잡한지 몰랐다, 올림픽의 마법 실현될 것"</a>
# title >> 바흐 IOC위원장 "얼마나 복잡한지 몰랐다, 올림픽의 마법 실현될 것"
# link >> https://n.news.naver.com/article/123/0002250663?ntype=RANKING
# url >> https://n.news.naver.com/article/123/0002250663?ntype=RANKING
# 1230002250663
# ord_id >> 1230002250663
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/123/0002250694?ntype=RANKING">"법치주의자 맞아?" 윤석열 전 총장 잇따른 직설화법으로 역풍 자초</a>
# title >> "법치주의자 맞아?" 윤석열 전 총장 잇따른 직설화법으로 역풍 자초
# link >> https://n.news.naver.com/article/123/0002250694?ntype=RANKING
# url >> https://n.news.naver.com/article/123/0002250694?ntype=RANKING
# 1230002250694
# ord_id >> 1230002250694
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/308/0000029121?ntype=RANKING">[단독] 낮엔 김학의 수사, 밤엔 ‘김봉현 술접대’ 받은 검사</a>
# title >> [단독] 낮엔 김학의 수사, 밤엔 ‘김봉현 술접대’ 받은 검사
# link >> https://n.news.naver.com/article/308/0000029121?ntype=RANKING
# url >> https://n.news.naver.com/article/308/0000029121?ntype=RANKING
# 3080000029121
# ord_id >> 3080000029121
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/308/0000029120?ntype=RANKING">밥 한 끼 위해 코로나 검사를 열여덟 번이나 받았다</a>
# title >> 밥 한 끼 위해 코로나 검사를 열여덟 번이나 받았다
# link >> https://n.news.naver.com/article/308/0000029120?ntype=RANKING
# url >> https://n.news.naver.com/article/308/0000029120?ntype=RANKING
# 3080000029120
# ord_id >> 3080000029120
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/308/0000029123?ntype=RANKING">‘4차 유행 언제 끝나지?’ 그보다 중요한 질문이 있다</a>
# title >> ‘4차 유행 언제 끝나지?’ 그보다 중요한 질문이 있다
# link >> https://n.news.naver.com/article/308/0000029123?ntype=RANKING
# url >> https://n.news.naver.com/article/308/0000029123?ntype=RANKING
# 3080000029123
# ord_id >> 3080000029123
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/024/0000069728?ntype=RANKING">슬금슬금 빠지는 집값…세종시에 무슨 일이</a>
# title >> 슬금슬금 빠지는 집값…세종시에 무슨 일이
# link >> https://n.news.naver.com/article/024/0000069728?ntype=RANKING
# url >> https://n.news.naver.com/article/024/0000069728?ntype=RANKING
# 0240000069728
# ord_id >> 0240000069728
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/024/0000069718?ntype=RANKING">‘렉키로나’ 인니서 코로나 치료제 승인…셀트리온 3형제 일제히 상승</a>
# title >> ‘렉키로나’ 인니서 코로나 치료제 승인…셀트리온 3형제 일제히 상승
# link >> https://n.news.naver.com/article/024/0000069718?ntype=RANKING
# url >> https://n.news.naver.com/article/024/0000069718?ntype=RANKING
# 0240000069718
# ord_id >> 0240000069718
# 링크는 >> <a class="list_title nclicks('RBP.rnknws')" href="https://n.news.naver.com/article/024/0000069719?ntype=RANKING">폭염이 살려놓은 원전관련주…원전 재가동 소식에 우진·한신기계 등 강세</a>
# title >> 폭염이 살려놓은 원전관련주…원전 재가동 소식에 우진·한신기계 등 강세
# link >> https://n.news.naver.com/article/024/0000069719?ntype=RANKING
# url >> https://n.news.naver.com/article/024/0000069719?ntype=RANKING
# 0240000069719
# ord_id >> 0240000069719

# %%
try:
    want_thing = input('정치, 경제, 사회, 생활, 세계, IT 중에 보고싶은 카테고리를 입력하세요.(모든 카테고리를 희망한다면 "모두"를 입력하세요) : ')
    what_press = input('어느 언론사의 기사들을 보시겠습니까. (모든 언론사를 원하신다면 "모두" 라고 입력하십시오)')
    cnt = int(input('각 언론사에서 몇개의 기사들을 보시겠습니까. (1~5의 값을 입력해주세요)'))

    
    for ranking in rankingnews:  # 각 언론사 랭킹 박스 리스트 for문
        press = ranking.find('strong', {'class' : 'rankingnews_name'}).text # 언론사 이름 ex) ytn, kbs, 서울경제 ...
        ranks = ranking.find_all('li') # 해당 언론사 리스트 랭킹
        count = 0
        for rank in ranks: # 해당 언론사 리스트 랭킹 for문
            if what_press not in press and what_press != '모두':
                continue

            count+=1
            if count > cnt:
                break;
            link = rank.find('a' , {'class' : "list_title nclicks('RBP.rnknws')"}) # 언론사 리스트 랭킹뉴스 링크
            
            if not link:
                continue
            elif link:
                ord_id, title, press, categoris, link = head_lines(link) # function
                if categoris == -1:
                    continue
                print(ord_id, title, press, categoris, link)
                sql = f"""insert into headlines values("{ord_id}", "{title}", "{press}", '{categoris}', '{link}');"""
                cursor.execute(sql)
                
                reporter, date, comment_cnt, keyword = detail_table(link) # function
                print(title, reporter, date, comment_cnt, keyword)
                print('---------------------------------------------------------------------------------------------\n\n')
                sql = f"""insert into detail_news values("{ord_id}", "{reporter}", "{date}", '{keyword}', {comment_cnt});"""
                cursor.execute(sql)
                time.sleep(1) # 1초 휴식
                db.commit() 
finally: # 에러발생 상관없이 실행
    db.close() # db 연결닫기

# %%
# SQL = "use naver_news"
# df = pd.read_sql(SQL, db)
# SQL = "SELECT * FROM headlines"
# df = pd.read_sql(SQL, db)
# df.to_csv('headlines.csv', sep=',', index=False, encoding='utf-8')
# SQL = "SELECT * FROM detail_news"
# df = pd.read_sql(SQL, db)
# df.to_csv('detail_news.csv', sep=',', index=False, encoding='utf-8')
# df
# Out:
# ---------------------------------------------------------------------------
# InterfaceError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1724         try:
# -> 1725             cur.execute(*args, **kwargs)
#    1726             return cur
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
# --> 547         self._execute_command(COMMAND.COM_QUERY, sql)
#     548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _execute_command(self, command, sql)
#     792         if not self._sock:
# --> 793             raise err.InterfaceError(0, "")
#     794
#
# InterfaceError: (0, '')
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1728             try:
# -> 1729                 self.con.rollback()
#    1730             except Exception as inner_exc:  # pragma: no cover
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in rollback(self)
#     478         """
# --> 479         self._execute_command(COMMAND.COM_QUERY, "ROLLBACK")
#     480         self._read_ok_packet()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pymysql\connections.py in _execute_command(self, command, sql)
#     792         if not self._sock:
# --> 793             raise err.InterfaceError(0, "")
#     794
#
# InterfaceError: (0, '')
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-159-9b6a2002b16e> in <module>
#       1 SQL = "SELECT * FROM headlines"
# ----> 2 df = pd.read_sql(SQL, db)
#       3 df.to_csv('headlines.csv', sep=',', index=False, encoding='utf-8')
#       4 SQL = "SELECT * FROM detail_news"
#       5 df = pd.read_sql(SQL, db)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     493
#     494     if isinstance(pandas_sql, SQLiteDatabase):
# --> 495         return pandas_sql.read_query(
#     496             sql,
#     497             index_col=index_col,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1769
#    1770         args = _convert_params(sql, params)
# -> 1771         cursor = self.execute(*args)
#    1772         columns = [col_desc[0] for col_desc in cursor.description]
#    1773
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1732                     f"Execution failed on sql: {args[0]}\n{exc}\nunable to rollback"
#    1733                 )
# -> 1734                 raise ex from inner_exc
#    1735
#    1736             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
#
# DatabaseError: Execution failed on sql: SELECT * FROM headlines
# (0, '')
# unable to rollback
